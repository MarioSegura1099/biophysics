# %% [markdown]
# # 12.9 BIFURCATION IN THE SINGLE-GENE TOGGLE
#
# ***This problem is only required for graduate and Honors students.***
#
# Use this notebook to store your work for this problem.

# %%
#*************************************************************
# Mario Segura
# Problem 11.2

#Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Image processing Function

from scipy.signal import convolve

# Import 3D plotting tool

from mpl_toolkits.mplot3d import Axes3D

# Random Generator

from numpy.random import default_rng
rng = default_rng()
rand = rng.random

# %% [markdown]
# ## Reproduce Figure 12.26(a).
#
# Make a plot that resembles the figure.  Indicate the points of intersection with markers that are a different color than the intersecting lines, and create at least one line that intersects the curve in three places.

# %%
x = np.linspace(0,.6,1000000)
f1 = 15*x
f2 = 12*x
f3 = 20*x
f4 = ((50*(x**2))/(1+(2*x**2)+(5*x**2)))+1
f5 = 10*x + 0.6

plt.figure(figsize = (16,9))
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.plot(x, f1, 'c')
plt.plot(x, f2, 'm')
plt.plot(x, f3, 'r')
plt.plot(x, f4, 'b')
plt.plot(x, f5, 'y')

plt.plot(.09, 1.4,'og', ms=5)
plt.plot(.06, 1.25,'og', ms=5)
plt.plot(.39, 4.7,'og', ms=5)

plt.plot(.06, 1.2,'or', ms=5)
plt.plot(.215, 2.75,'or', ms=5)
plt.plot(.48, 5.45,'or', ms=5)

plt.show()

# %% [markdown]
# The red, cyan, and purple lines represent the linear lines that were in the figure. The green points are the point of intersection of the those lines with the blue curve. The yellow line is the line created to intersect with the blue curve three times, the points being those in red.

# %% [markdown]
# ## Find the bifurcations.
#
# Use trial and error or a numerical solver to find th ecritical values of $M$ when bifurcations occur — when you go from having a single point of intersection to three.
