# %% [markdown]
# # 10.2 MEMBRANE CONDUCTANCE
#
# ***This problem is only required for graduate and Honors students.***
#
# Use this notebook to store your work for this problem.

# %%
#*************************************************************
# Mario Segura
# Problem 10.2

#Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#************************************
Data = np.load('colquhounData.npy')
Div = np.hsplit(Data,2)
Bins = Div[0].flatten()
Channels = Div[1].flatten()
Total_Channels = Data.sum()
Total_Channels
# Out:
# 553.0

# %% [markdown]
# ## (a)

# %%
N = Channels.sum()
N
O_Channels = Channels.cumsum()
O_Channels
# Out:
# array([ 69., 119., 162., 198., 224., 249., 269., 290., 307., 320., 329.,
#        344., 356., 367., 378., 381., 386., 389., 393., 397., 400., 401.,
#        403., 403.])

# %% [markdown]
# ## (b)

# %%
#***********Number of Closed Channels******
plt.figure()
plt.title('Number of Closed Channels')
plt.plot(Bins,Channels)

#**********Number of Open Channels*********
plt.figure()
plt.title('Number of Open Channels')
plt.plot(Bins,O_Channels)

# %% [markdown]
# The plot that displays the number of closings data seems to be the noisiest of the two. This could be due to the randomness in opending.

# %% [markdown]
# ## (c)

# %%
#*******Initial Beta Guess***********
Beta = 60
Draws = 100
P = np.random.exponential(Beta, Draws)
P
# Out:
# array([ 22.42904335,   5.8094262 ,  69.09010297,  10.31653693,
#         34.59197864,  10.23851171,   7.35453041,  57.87634377,
#         44.06598997,  50.48692048,  23.31976923,  80.29169537,
#         62.18275409,  25.9446446 ,  33.63506912,  56.30193194,
#         43.97706764,  33.32096204,  66.27508806, 129.31838107,
#         38.46953353, 202.15967148,   6.14380811, 294.5981426 ,
#          3.99190363,   0.73900369,   4.77537948,  21.05583769,
#         20.75037517,  21.67834628,  14.57634199,  19.22500364,
#        327.72178456,  47.17146267,   2.29177091,  38.74104943,
#        179.63253299,  79.95912834,  43.98496915,  31.95416466,
#        180.73621723,   7.5141216 ,  22.58440431, 100.52053176,
#         71.26752768, 161.86341253,  24.11102623,  26.76258354,
#         59.13141848,  82.69955192, 190.56005999,  14.7284372 ,
#         26.72390094,   6.01524263,  77.73864334, 141.71766012,
#          2.40016887,  29.65803522,  43.00944873,  48.2580117 ,
# ...

# %% [markdown]
# ## (d)

# %%
#***********Plotting Data in Histogram***********
plt.figure()
plt.hist(P, bins = 10, color='green')

plt.figure()
plt.hist(Channels)
# Out:
# (array([9., 5., 3., 3., 0., 1., 1., 1., 0., 1.]),
#  array([ 0. ,  6.9, 13.8, 20.7, 27.6, 34.5, 41.4, 48.3, 55.2, 62.1, 69. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## (e)

# %%
#*******Initial Beta Guess***********
Beta = 15
Draws = 55
P = np.random.exponential(Beta, Draws)
#***********Plotting Data in Histogram***********
plt.figure()
plt.hist(P,color='green')

plt.figure()
plt.hist(Channels)
# Out:
# (array([9., 5., 3., 3., 0., 1., 1., 1., 0., 1.]),
#  array([ 0. ,  6.9, 13.8, 20.7, 27.6, 34.5, 41.4, 48.3, 55.2, 62.1, 69. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## (f)

# %%
Beta = 15
Draws = 55

for i in range(10):
    P = np.random.exponential(Beta, Draws)
    plt.hist(P)
    
plt.figure()
plt.hist(Channels)
# Out:
# (array([9., 5., 3., 3., 0., 1., 1., 1., 0., 1.]),
#  array([ 0. ,  6.9, 13.8, 20.7, 27.6, 34.5, 41.4, 48.3, 55.2, 62.1, 69. ]),
#  <BarContainer object of 10 artists>)
