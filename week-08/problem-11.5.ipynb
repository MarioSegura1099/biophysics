# %% [markdown]
# # 11.5 PENDULUM PHASE PORTRAIT
#
# Use this notebook to store your work for this problem.

# %%
#*************************************************************
# Mario Segura
# Problem 11.5

#Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Image processing Function

from scipy.signal import convolve

# Import 3D plotting tool

from mpl_toolkits.mplot3d import Axes3D

# Random Generator

from numpy.random import default_rng
rng = default_rng()
rand = rng.random

# integral
from scipy.integrate import odeint

# %% [markdown]
# ## (a) Plot the phase portrait.

# %%
m = 1
g = 3
xi = 1
L = 1
o = 0

theta = np.linspace(-np.pi,np.pi,101)

 
o_angle = -((m*g*np.sin(theta)) + (xi*L*o))/ (m*L)
plt.plot(theta, o_angle, 'r')

#Meshgrid
x = np.linspace(-3,3,15)
y = np.linspace(-3,3,15)

X, Y = np.meshgrid(x,y)
vX = Y
vY = -X
plt.quiver(X,Y,vX,vY, pivot='mid')

#

# %% [markdown]
# ## (b) Describe the motion.

# %% [markdown]
# ***Replace with your comments.***
